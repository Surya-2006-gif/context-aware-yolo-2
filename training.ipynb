# %%
from ultralytics import YOLO

# %%
data_yaml_path = r"C:\Users\surya\Desktop\computer vision\Hopfield networks\dataset\data.yaml"

# %%
model = YOLO("yolo11s-obb.pt")  # build a new model from YAML

# %%
results = model.train(data=data_yaml_path, epochs=30, imgsz=240,)
# Out:
# Ultralytics 8.3.204  Python-3.10.18 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4050 Laptop GPU, 6140MiB)
# ...
